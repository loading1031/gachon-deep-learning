# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("./diabetes.csv", index_col=0)
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# 1                               0.351   31        0
# 8                               0.672   32        1
# 1                               0.167   21        0
# 0                               2.288   33        1
# ...                               ...  ...      ...
# 10                              0.171   63        0
# 2                               0.340   27        0
# 5                               0.245   30        0
# 1                               0.349   47        1
# 1                               0.315   23        0
#
# [768 rows x 8 columns]

# %% [markdown]
# ### 이상치 확인, 산점도 등은 1번에서 이미 진행하였으므로 생략

# %%
X=df.drop('Outcome',axis=1)
X.head()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
#
#              DiabetesPedigreeFunction  Age
# Pregnancies
# 6                               0.627   50
# 1                               0.351   31
# 8                               0.672   32
# 1                               0.167   21
# 0                               2.288   33

# %%
y=df['Outcome']
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# # 원 핫 인코딩

# %%
Y = pd.get_dummies(y).values
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %% [markdown]
# # Numpy 변환

# %%
X = X.values

# %%
X.shape
# Out:
# (768, 7)

# %%
Y
# 일반적으로 원-핫 인코딩은 0과 1의 숫자 값을 사용하지만, 
# 특정 상황이나 설정에 따라 불리언 값(True/False)으로 표현될 수 있음.
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(10,input_shape=(7,),activation='relu'))
model.add(Dense(8,activation='tanh'))
model.add(Dense(6,activation='tanh'))
model.add(Dense(2,activation='softmax'))

model.compile(Adam(learning_rate=0.04),'categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 10)                80
#
#  dense_9 (Dense)             (None, 8)                 88
#
#  dense_10 (Dense)            (None, 6)                 54
#
#  dense_11 (Dense)            (None, 2)                 14
#
# =================================================================
# Total params: 236
# Trainable params: 236
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 2024-09-11 00:17:15.539101: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6858 - accuracy: 0.5977 - val_loss: 0.6480 - val_accuracy: 0.6948
# Epoch 2/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6584 - accuracy: 0.6401 - val_loss: 0.6326 - val_accuracy: 0.6948
# Epoch 3/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6566 - accuracy: 0.6401 - val_loss: 0.6276 - val_accuracy: 0.6948
# Epoch 4/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6599 - accuracy: 0.6401 - val_loss: 0.6258 - val_accuracy: 0.6948
# Epoch 5/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6664 - accuracy: 0.6401 - val_loss: 0.6292 - val_accuracy: 0.6948
# Epoch 6/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6630 - accuracy: 0.6401 - val_loss: 0.6434 - val_accuracy: 0.6948
# Epoch 7/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6638 - accuracy: 0.6401 - val_loss: 0.6157 - val_accuracy: 0.6948
# Epoch 8/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6590 - accuracy: 0.6401 - val_loss: 0.6208 - val_accuracy: 0.6948
# Epoch 9/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6710 - accuracy: 0.6401 - val_loss: 0.6155 - val_accuracy: 0.6948
# Epoch 10/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6605 - accuracy: 0.6401 - val_loss: 0.6154 - val_accuracy: 0.6948
# Epoch 11/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6654 - accuracy: 0.6401 - val_loss: 0.6163 - val_accuracy: 0.6948
# Epoch 12/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6593 - accuracy: 0.6401 - val_loss: 0.6152 - val_accuracy: 0.6948
# Epoch 13/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6691 - accuracy: 0.5847 - val_loss: 0.6733 - val_accuracy: 0.6948
# Epoch 14/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.5749 - val_loss: 0.6152 - val_accuracy: 0.6948
# Epoch 15/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6640 - accuracy: 0.6401 - val_loss: 0.6198 - val_accuracy: 0.6948
# Epoch 16/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6592 - accuracy: 0.6401 - val_loss: 0.6152 - val_accuracy: 0.6948
# Epoch 17/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6654 - accuracy: 0.6401 - val_loss: 0.6179 - val_accuracy: 0.6948
# Epoch 18/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6541 - accuracy: 0.6401 - val_loss: 0.6500 - val_accuracy: 0.6948
# Epoch 19/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6600 - accuracy: 0.6401 - val_loss: 0.6666 - val_accuracy: 0.6948
# Epoch 20/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6624 - accuracy: 0.6401 - val_loss: 0.6448 - val_accuracy: 0.6948
# Epoch 21/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6613 - accuracy: 0.6401 - val_loss: 0.6194 - val_accuracy: 0.6948
# Epoch 22/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6642 - accuracy: 0.6401 - val_loss: 0.6184 - val_accuracy: 0.6948
# Epoch 23/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6843 - accuracy: 0.6401 - val_loss: 0.6224 - val_accuracy: 0.6948
# Epoch 24/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6635 - accuracy: 0.6401 - val_loss: 0.6207 - val_accuracy: 0.6948
# Epoch 25/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6598 - accuracy: 0.6401 - val_loss: 0.6303 - val_accuracy: 0.6948
# Epoch 26/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6536 - accuracy: 0.6401 - val_loss: 0.6524 - val_accuracy: 0.6948
# Epoch 27/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6592 - accuracy: 0.6401 - val_loss: 0.6306 - val_accuracy: 0.6948
# Epoch 28/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6608 - accuracy: 0.6401 - val_loss: 0.6541 - val_accuracy: 0.6948
# Epoch 29/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6572 - accuracy: 0.6401 - val_loss: 0.6154 - val_accuracy: 0.6948
# Epoch 30/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6641 - accuracy: 0.6401 - val_loss: 0.6159 - val_accuracy: 0.6948
# 5/5 [==============================] - 0s 723us/step

# %%
import matplotlib.pyplot as plt

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class, zero_division=0))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.82       107
#            1       0.00      0.00      0.00        47
#
#     accuracy                           0.69       154
#    macro avg       0.35      0.50      0.41       154
# weighted avg       0.48      0.69      0.57       154
#
# [[107   0]
#  [ 47   0]]
