# %% [markdown]
# ## 2. 동일한 데이터로 딥러닝 분류 수행하라. (dense layer 만 사용)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ### 이상치 확인, 산점도 등은 1번에서 이미 진행하였으므로 생략

# %%
X=df.drop('Outcome',axis=1)
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y=df['Outcome']
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# # 원 핫 인코딩

# %%
Y = pd.get_dummies(y).values

# %% [markdown]
# # Numpy 변환

# %%
X = X.values

# %%
X.shape
# Out:
# (768, 8)

# %%
Y
# 일반적으로 원-핫 인코딩은 0과 1의 숫자 값을 사용하지만, 
# 특정 상황이나 설정에 따라 불리언 값(True/False)으로 표현될 수 있음.
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam


model = Sequential()

model.add(Dense(10,input_shape=(8,),activation='tanh'))
model.add(Dense(8,activation='tanh'))
model.add(Dense(6,activation='tanh'))
model.add(Dense(2,activation='sigmoid'))

model.compile(Adam(learning_rate=0.04),'binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                90
#
#  dense_5 (Dense)             (None, 8)                 88
#
#  dense_6 (Dense)             (None, 6)                 54
#
#  dense_7 (Dense)             (None, 2)                 14
#
# =================================================================
# Total params: 246
# Trainable params: 246
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6727 - accuracy: 0.6205 - val_loss: 0.6409 - val_accuracy: 0.6948
# Epoch 2/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6542 - accuracy: 0.6401 - val_loss: 0.6188 - val_accuracy: 0.6948
# Epoch 3/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6568 - accuracy: 0.6401 - val_loss: 0.6211 - val_accuracy: 0.6948
# Epoch 4/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6562 - accuracy: 0.6401 - val_loss: 0.6203 - val_accuracy: 0.6948
# Epoch 5/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6593 - accuracy: 0.6401 - val_loss: 0.6430 - val_accuracy: 0.6948
# Epoch 6/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6595 - accuracy: 0.6401 - val_loss: 0.6305 - val_accuracy: 0.6948
# Epoch 7/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6642 - accuracy: 0.6401 - val_loss: 0.6280 - val_accuracy: 0.6948
# Epoch 8/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.6401 - val_loss: 0.6225 - val_accuracy: 0.6948
# Epoch 9/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6557 - accuracy: 0.6401 - val_loss: 0.6193 - val_accuracy: 0.6948
# Epoch 10/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6588 - accuracy: 0.6401 - val_loss: 0.6154 - val_accuracy: 0.6948
# Epoch 11/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6667 - accuracy: 0.6401 - val_loss: 0.6159 - val_accuracy: 0.6948
# Epoch 12/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6650 - accuracy: 0.6401 - val_loss: 0.6199 - val_accuracy: 0.6948
# Epoch 13/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6824 - accuracy: 0.6401 - val_loss: 0.6169 - val_accuracy: 0.6948
# Epoch 14/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6665 - accuracy: 0.6401 - val_loss: 0.6251 - val_accuracy: 0.6948
# Epoch 15/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6579 - accuracy: 0.6401 - val_loss: 0.6360 - val_accuracy: 0.6948
# Epoch 16/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6569 - accuracy: 0.6401 - val_loss: 0.6384 - val_accuracy: 0.6948
# Epoch 17/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6552 - accuracy: 0.6401 - val_loss: 0.6154 - val_accuracy: 0.6948
# Epoch 18/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6657 - accuracy: 0.6401 - val_loss: 0.6314 - val_accuracy: 0.6948
# Epoch 19/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6545 - accuracy: 0.6401 - val_loss: 0.6170 - val_accuracy: 0.6948
# Epoch 20/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6558 - accuracy: 0.6401 - val_loss: 0.6311 - val_accuracy: 0.6948
# Epoch 21/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6562 - accuracy: 0.6401 - val_loss: 0.6199 - val_accuracy: 0.6948
# Epoch 22/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6597 - accuracy: 0.6401 - val_loss: 0.6331 - val_accuracy: 0.6948
# Epoch 23/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6573 - accuracy: 0.6401 - val_loss: 0.6192 - val_accuracy: 0.6948
# Epoch 24/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6571 - accuracy: 0.6401 - val_loss: 0.6314 - val_accuracy: 0.6948
# Epoch 25/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6576 - accuracy: 0.6401 - val_loss: 0.6190 - val_accuracy: 0.6948
# Epoch 26/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6556 - accuracy: 0.6401 - val_loss: 0.6288 - val_accuracy: 0.6948
# Epoch 27/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6594 - accuracy: 0.6401 - val_loss: 0.6371 - val_accuracy: 0.6948
# Epoch 28/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6594 - accuracy: 0.6401 - val_loss: 0.6230 - val_accuracy: 0.6948
# Epoch 29/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6574 - accuracy: 0.6401 - val_loss: 0.6255 - val_accuracy: 0.6948
# Epoch 30/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6542 - accuracy: 0.6401 - val_loss: 0.6153 - val_accuracy: 0.6948
# 5/5 [==============================] - 0s 681us/step

# %%
import matplotlib.pyplot as plt

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class, zero_division=0))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.82       107
#            1       0.00      0.00      0.00        47
#
#     accuracy                           0.69       154
#    macro avg       0.35      0.50      0.41       154
# weighted avg       0.48      0.69      0.57       154
#
# [[107   0]
#  [ 47   0]]
